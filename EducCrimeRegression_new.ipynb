# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
Budget = pd.read_csv('actualls_all.csv')
Budget.head()
# Out:
#         State         Total     Alabama     Alaska     Arizona   Arkansas  \
# 0  state_abbr           NaN          AL         AK          AZ         AR
# 1    latitude           NaN      32.799     61.385     33.7712    34.9513
# 2   longitude           NaN    -86.8073  -152.2683   -111.3877   -92.3809
# 3        2000  3.107050e+10   557767814  177881580   667976456  328403457
# 4        2001  7.125435e+10  1205096441  227988480  1990909460  618218324
#
#    California    Colorado Connecticut   Delaware    ...     South Dakota  \
# 0          CA          CO          CT         DE    ...               SD
# 1       36.17     39.0646     41.5834    39.3498    ...          44.2853
# 2   -119.7462   -105.3272    -72.7622   -75.5148    ...         -99.4632
# 3  3792096590   370882855   288895735   85735787    ...        133366735
# 4  7895473833  1061188114   703315579  187754734    ...        296723889
#
#     Tennessee       Texas       Utah    Vermont    Virginia  Washington  \
# ...

# %%
#education_df = education_df.drop(education_df.index[[0,1,2]])
Budget = Budget.drop(Budget.index[[[0,1,2]]])
Budget.head()
# Out:
#   State         Total     Alabama     Alaska     Arizona   Arkansas  \
# 3  2000  3.107050e+10   557767814  177881580   667976456  328403457
# 4  2001  7.125435e+10  1205096441  227988480  1990909460  618218324
# 5  2002  8.240055e+10  1387975241  260180178  2520137525  733650835
# 6  2003  9.260448e+10  1584581070  280079667  3103945066  829601733
# 7  2004  1.010000e+11  1672101861  299103691  4312713049  888970231
#
#     California    Colorado Connecticut   Delaware    ...     South Dakota  \
# 3   3792096590   370882855   288895735   85735787    ...        133366735
# 4   7895473833  1061188114   703315579  187754734    ...        296723889
# 5   9092121808  1238777106   825970250  216149404    ...        342344861
# 6   9928105199  1416997560   908683240  226632147    ...        373160375
# 7  10825485264  1665593582   965299387  286492122    ...        375611344
#
#     Tennessee       Texas       Utah    Vermont    Virginia  Washington  \
# ...

# %%
Budget = Budget.drop(['Total'], axis=1)
Budget.head()
# Out:
#   State     Alabama     Alaska     Arizona   Arkansas   California  \
# 3  2000   557767814  177881580   667976456  328403457   3792096590
# 4  2001  1205096441  227988480  1990909460  618218324   7895473833
# 5  2002  1387975241  260180178  2520137525  733650835   9092121808
# 6  2003  1584581070  280079667  3103945066  829601733   9928105199
# 7  2004  1672101861  299103691  4312713049  888970231  10825485264
#
#      Colorado Connecticut   Delaware     Florida    ...     South Dakota  \
# 3   370882855   288895735   85735787  1590311741    ...        133366735
# 4  1061188114   703315579  187754734  3622745422    ...        296723889
# 5  1238777106   825970250  216149404  4124966740    ...        342344861
# 6  1416997560   908683240  226632147  4631097940    ...        373160375
# 7  1665593582   965299387  286492122  5181788479    ...        375611344
#
#     Tennessee       Texas       Utah    Vermont    Virginia  Washington  \
# ...

# %%
Budget = Budget.rename(index=str, columns={"State": "Year"})
Budget.head()
# Out:
#    Year     Alabama     Alaska     Arizona   Arkansas   California  \
# 3  2000   557767814  177881580   667976456  328403457   3792096590
# 4  2001  1205096441  227988480  1990909460  618218324   7895473833
# 5  2002  1387975241  260180178  2520137525  733650835   9092121808
# 6  2003  1584581070  280079667  3103945066  829601733   9928105199
# 7  2004  1672101861  299103691  4312713049  888970231  10825485264
#
#      Colorado Connecticut   Delaware     Florida    ...     South Dakota  \
# 3   370882855   288895735   85735787  1590311741    ...        133366735
# 4  1061188114   703315579  187754734  3622745422    ...        296723889
# 5  1238777106   825970250  216149404  4124966740    ...        342344861
# 6  1416997560   908683240  226632147  4631097940    ...        373160375
# 7  1665593582   965299387  286492122  5181788479    ...        375611344
#
#     Tennessee       Texas       Utah    Vermont    Virginia  Washington  \
# ...

# %%
Budget.reset_index(inplace=True)
Budget.head()
# Out:
#   index  Year     Alabama     Alaska     Arizona   Arkansas   California  \
# 0     3  2000   557767814  177881580   667976456  328403457   3792096590
# 1     4  2001  1205096441  227988480  1990909460  618218324   7895473833
# 2     5  2002  1387975241  260180178  2520137525  733650835   9092121808
# 3     6  2003  1584581070  280079667  3103945066  829601733   9928105199
# 4     7  2004  1672101861  299103691  4312713049  888970231  10825485264
#
#      Colorado Connecticut   Delaware    ...     South Dakota   Tennessee  \
# 0   370882855   288895735   85735787    ...        133366735   583465744
# 1  1061188114   703315579  187754734    ...        296723889  1326565262
# 2  1238777106   825970250  216149404    ...        342344861  1514613174
# 3  1416997560   908683240  226632147    ...        373160375  1705965593
# 4  1665593582   965299387  286492122    ...        375611344  1895812898
#
#         Texas       Utah    Vermont    Virginia  Washington West Virginia  \
# ...

# %%
Crime = pd.read_csv('crime_all.csv')
Crime.head()
# Out:
#    State  ALABAMA  ALASKA  ARIZONA  ARKANSAS  CALIFORNIA  COLORADO  \
# 0   2000   202159   26641   299092    110019     1266714    171304
# 1   2001   192835   26895   322549    111296     1346557    186379
# 2   2002   200331   27745   348467    112672     1384872    195936
# 3   2003   201572   28130   342973    111141     1420637    195046
# 4   2004   201664   26331   335699    124201     1425264    197527
#
#    CONNECTICUT  DELAWARE  FLORIDA   ...     SOUTH DAKOTA  TENNESSEE    TEXAS  \
# 0       110091     35090   910154   ...            17511     278218  1033311
# 1       106791     32267   913230   ...            17644     295770  1098809
# 2       103719     31803   905957   ...            17342     290961  1130292
# 3       101537     33046   881976   ...            16624     296010  1138623
# 4       102078     30992   850895   ...            16227     295147  1132256
#
#      UTAH  VERMONT  VIRGINIA  WASHINGTON  WEST VIRGINIA  WISCONSIN  WYOMING
# ...

# %%
Crime = Crime.rename(index=str, columns={"State": "Year"})
Crime.head()
# Out:
#    Year  ALABAMA  ALASKA  ARIZONA  ARKANSAS  CALIFORNIA  COLORADO  \
# 0  2000   202159   26641   299092    110019     1266714    171304
# 1  2001   192835   26895   322549    111296     1346557    186379
# 2  2002   200331   27745   348467    112672     1384872    195936
# 3  2003   201572   28130   342973    111141     1420637    195046
# 4  2004   201664   26331   335699    124201     1425264    197527
#
#    CONNECTICUT  DELAWARE  FLORIDA   ...     SOUTH DAKOTA  TENNESSEE    TEXAS  \
# 0       110091     35090   910154   ...            17511     278218  1033311
# 1       106791     32267   913230   ...            17644     295770  1098809
# 2       103719     31803   905957   ...            17342     290961  1130292
# 3       101537     33046   881976   ...            16624     296010  1138623
# 4       102078     30992   850895   ...            16227     295147  1132256
#
#      UTAH  VERMONT  VIRGINIA  WASHINGTON  WEST VIRGINIA  WISCONSIN  WYOMING
# ...

# %%
Crime = Crime.drop(Crime.index[[[11]]])
Crime.head()
# Out:
#    Year  ALABAMA  ALASKA  ARIZONA  ARKANSAS  CALIFORNIA  COLORADO  \
# 0  2000   202159   26641   299092    110019     1266714    171304
# 1  2001   192835   26895   322549    111296     1346557    186379
# 2  2002   200331   27745   348467    112672     1384872    195936
# 3  2003   201572   28130   342973    111141     1420637    195046
# 4  2004   201664   26331   335699    124201     1425264    197527
#
#    CONNECTICUT  DELAWARE  FLORIDA   ...     SOUTH DAKOTA  TENNESSEE    TEXAS  \
# 0       110091     35090   910154   ...            17511     278218  1033311
# 1       106791     32267   913230   ...            17644     295770  1098809
# 2       103719     31803   905957   ...            17342     290961  1130292
# 3       101537     33046   881976   ...            16624     296010  1138623
# 4       102078     30992   850895   ...            16227     295147  1132256
#
#      UTAH  VERMONT  VIRGINIA  WASHINGTON  WEST VIRGINIA  WISCONSIN  WYOMING
# ...

# %%
Crime.reset_index(inplace=True)
Crime.head()
# Out:
#   index  Year  ALABAMA  ALASKA  ARIZONA  ARKANSAS  CALIFORNIA  COLORADO  \
# 0     0  2000   202159   26641   299092    110019     1266714    171304
# 1     1  2001   192835   26895   322549    111296     1346557    186379
# 2     2  2002   200331   27745   348467    112672     1384872    195936
# 3     3  2003   201572   28130   342973    111141     1420637    195046
# 4     4  2004   201664   26331   335699    124201     1425264    197527
#
#    CONNECTICUT  DELAWARE   ...     SOUTH DAKOTA  TENNESSEE    TEXAS    UTAH  \
# 0       110091     35090   ...            17511     278218  1033311   99958
# 1       106791     32267   ...            17644     295770  1098809   96307
# 2       103719     31803   ...            17342     290961  1130292  103129
# 3       101537     33046   ...            16624     296010  1138623  105207
# 4       102078     30992   ...            16227     295147  1132256  103246
#
#    VERMONT  VIRGINIA  WASHINGTON  WEST VIRGINIA  WISCONSIN  WYOMING
# ...

# %%
Budget.head
# Out:
# <bound method NDFrame.head of    index  Year     Alabama     Alaska      Arizona    Arkansas   California  \
# 0      3  2000   557767814  177881580    667976456   328403457   3792096590
# 1      4  2001  1205096441  227988480   1990909460   618218324   7895473833
# 2      5  2002  1387975241  260180178   2520137525   733650835   9092121808
# 3      6  2003  1584581070  280079667   3103945066   829601733   9928105199
# 4      7  2004  1672101861  299103691   4312713049   888970231  10825485264
# 5      8  2005  1677873818  304062005   4678691268   930347440  11080946384
# 6      9  2006  1658852571  301221949   5024773228   943608285  11259250170
# 7     10  2007  1774144162  305996184   5864572510   988744641  11912567291
# 8     11  2008  1986869436  318560716   6375493472  1046683517  12912570108
# 9     12  2009  2472093599  347373460   8052788118  1303196239  15405843838
# 10    13  2010  3061491531  427620917  10181765748  1542976136  18401548959
#
# ...

# %%
Crime.head
# Out:
# <bound method NDFrame.head of     Year  ALABAMA  ALASKA  ARIZONA  ARKANSAS  CALIFORNIA  COLORADO  \
# 0   2000   202159   26641   299092    110019     1266714    171304
# 1   2001   192835   26895   322549    111296     1346557    186379
# 2   2002   200331   27745   348467    112672     1384872    195936
# 3   2003   201572   28130   342973    111141     1420637    195046
# 4   2004   201664   26331   335699    124201     1425264    197527
# 5   2005   197071   28169   317823    127434     1390709    206947
# 6   2006   200578   28765   316286    127027     1350137    182670
# 7   2007   204530   27617   310394    127068     1299685    163047
# 8   2008   211454   24598   307979    123882     1265920    157671
# 9   2009   198808   24998   261511    123997     1184073    150944
# 10  2010   186148   24796   251978    118510     1146072    151125
#
#     CONNECTICUT  DELAWARE  FLORIDA   ...     SOUTH DAKOTA  TENNESSEE    TEXAS  \
# ...

# %%
educrime_df = pd.merge(Budget, Crime, on='index')
educrime_df.head()
# Out:
#   index Year_x     Alabama     Alaska     Arizona   Arkansas   California  \
# 0     3   2000   557767814  177881580   667976456  328403457   3792096590
# 1     4   2001  1205096441  227988480  1990909460  618218324   7895473833
# 2     5   2002  1387975241  260180178  2520137525  733650835   9092121808
# 3     6   2003  1584581070  280079667  3103945066  829601733   9928105199
# 4     7   2004  1672101861  299103691  4312713049  888970231  10825485264
#
#      Colorado Connecticut   Delaware   ...   SOUTH DAKOTA TENNESSEE    TEXAS  \
# 0   370882855   288895735   85735787   ...          16624    296010  1138623
# 1  1061188114   703315579  187754734   ...          16227    295147  1132256
# 2  1238777106   825970250  216149404   ...          15147    299839  1111384
# 3  1416997560   908683240  226632147   ...          14004    295204  1080838
# 4  1665593582   965299387  286492122   ...          14503    298104  1107196
#
# ...

# %%
educrime_df.head(10)
# Out:
#   index Year_x     Alabama     Alaska     Arizona   Arkansas   California  \
# 0     3   2000   557767814  177881580   667976456  328403457   3792096590
# 1     4   2001  1205096441  227988480  1990909460  618218324   7895473833
# 2     5   2002  1387975241  260180178  2520137525  733650835   9092121808
# 3     6   2003  1584581070  280079667  3103945066  829601733   9928105199
# 4     7   2004  1672101861  299103691  4312713049  888970231  10825485264
# 5     8   2005  1677873818  304062005  4678691268  930347440  11080946384
# 6     9   2006  1658852571  301221949  5024773228  943608285  11259250170
# 7    10   2007  1774144162  305996184  5864572510  988744641  11912567291
#
#      Colorado Connecticut   Delaware   ...   SOUTH DAKOTA TENNESSEE    TEXAS  \
# 0   370882855   288895735   85735787   ...          16624    296010  1138623
# 1  1061188114   703315579  187754734   ...          16227    295147  1132256
# ...

# %%
print(educrime_df.columns.values)
# Out:
# ['index' 'Year_x' 'Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California'
#  'Colorado' 'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho'
#  'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine'
#  'Maryland' 'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri'
#  'Montana' 'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico'
#  'New York' 'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon'
#  'Pennsylvania' 'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee'
#  'Texas' 'Utah' 'Vermont' 'Virginia' 'Washington' 'West Virginia'
#  'Wisconsin' 'Wyoming' 'Year_y' 'ALABAMA' 'ALASKA' 'ARIZONA' 'ARKANSAS'
#  'CALIFORNIA' 'COLORADO' 'CONNECTICUT' 'DELAWARE' 'FLORIDA' 'GEORGIA'
#  'HAWAII' 'IDAHO' 'ILLINOIS' 'INDIANA' 'IOWA' 'KANSAS' 'KENTUCKY'
#  'LOUISIANA' 'MAINE' 'MARYLAND' 'MASSACHUSETTS' 'MICHIGAN' 'MINNESOTA'
#  'MISSISSIPPI' 'MISSOURI' 'MONTANA' 'NEBRASKA' 'NEVADA' 'NEW HAMPSHIRE'
# ...

# %%
X = educrime_df[['Alabama','Alaska','Arizona','Arkansas', 'California','Colorado','Connecticut','Delaware','Florida',
                 'Georgia','Hawaii','Idaho','Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine',
                 'Maryland','Massachusetts','Michigan','Minnesota','Mississippi','Missouri',
                 'Montana','Nebraska','Nevada','New Hampshire','New Jersey','New Mexico',
                 'New York','North Carolina','North Dakota','Ohio','Oklahoma','Oregon',
                 'Pennsylvania','Rhode Island','South Carolina','South Dakota','Tennessee',
                 'Texas','Utah','Vermont','Virginia','Washington','West Virginia',
                 'Wisconsin','Wyoming']].values.reshape(-1,1)

y = educrime_df[['ALABAMA', 'ALASKA', 'ARIZONA', 'ARKANSAS',
 'CALIFORNIA', 'COLORADO', 'CONNECTICUT', 'DELAWARE', 'FLORIDA', 'GEORGIA',
 'HAWAII', 'IDAHO', 'ILLINOIS', 'INDIANA', 'IOWA', 'KANSAS', 'KENTUCKY',
 'LOUISIANA', 'MAINE', 'MARYLAND', 'MASSACHUSETTS', 'MICHIGAN', 'MINNESOTA',
 'MISSISSIPPI', 'MISSOURI', 'MONTANA', 'NEBRASKA', 'NEVADA', 'NEW HAMPSHIRE',
 'NEW JERSEY', 'NEW MEXICO', 'NEW YORK', 'NORTH CAROLINA', 'NORTH DAKOTA',
 'OHIO', 'OKLAHOMA', 'OREGON', 'PENNSYLVANIA', 'RHODE ISLAND', 'SOUTH CAROLINA',
 'SOUTH DAKOTA', 'TENNESSEE', 'TEXAS', 'UTAH', 'VERMONT', 'VIRGINIA',
 'WASHINGTON', 'WEST VIRGINIA', 'WISCONSIN', 'WYOMING']].values.reshape(-1,1)

print(X.shape, y.shape)
# Out:
# (400, 1) (400, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create the model using LinearRegression
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.7370377744175338
# Testing Score: 0.560034768040832

# %%
# Plot the Residuals for the Training and Testing data

plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
# Out:
# Text(0.5,1,'Residual Plot')

# %%
y_train.shape
# Out:
# (300, 1)

# %%
#plt.scatter(X_train['2005_x'], model.predict(X_train))
#plt.scatter(X_train['2005_x'], y_train)

# %%
educrime_y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
# The coefficients
print('Coefficients: \n', model.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, educrime_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, educrime_y_pred))
# Out:
# Coefficients:
#  [[ 0.0001107]]
# Mean squared error: 25084524872.71
# Variance score: 0.56

# %%
print(X_test)
# Out:
# [['3047639805']
#  ['747461489']
#  ['117810518']
#  ['328434252']
#  ['510599570']
#  ['2954518787']
#  ['2122576555']
#  ['253879970']
#  ['1499444374']
#  ['561372404']
#  ['822536045']
#  ['484532926']
#  ['703315579']
#  ['1266655860']
#  ['1942521331']
#  ['2484215057']
#  ['432014135']
#  ['750456923']
#  ['8106090202']
#  ['1369915637']
#  ['259985925']
#  ['296011073']
#  ['2132145240']
#  ['3612333060']
#  ['557767814']
#  ['1775557207']
#  ['1050102995']
#  ['376050552']
#  ['4728937533']
#  ['9092121808']
#  ['2668430091']
#  ['674510076']
#  ['468785354']
#  ['187754734']
#  ['2315149754']
#  ['1097466524']
#  ['1831992075']
#  ['7792289367']
#  ['4631097940']
#  ['1514613174']
#  ['8514733210']
#  ['1061188114']
#  ['498722144']
#  ['156536540']
#  ['1641764159']
#  ['2712595650']
#  ['1357291868']
#  ['7590280856']
#  ['465781969']
#  ['1030626853']
#  ['569577741']
#  ['3734005600']
#  ['552904039']
#  ['1908834439']
#  ['2510828590']
#  ['443090828']
# ...

# %%
# Plot outputs
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, educrime_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
print(np.round(educrime_y_pred,2))
# Out:
# [[  365640.73]
#  [  111018.72]
#  [   41318.48]
#  [   64633.82]
#  [   84798.9 ]
#  [  355332.54]
#  [  263239.33]
#  [   56380.91]
#  [  194260.7 ]
#  [   90419.29]
#  [  119329.22]
#  [   81913.41]
#  [  106131.92]
#  [  168491.79]
#  [  243307.83]
#  [  303271.5 ]
#  [   76099.76]
#  [  111350.31]
#  [  925594.17]
#  [  179922.3 ]
#  [   57056.82]
#  [   61044.68]
#  [  264298.56]
#  [  428150.37]
#  [   90020.27]
#  [  224825.46]
#  [  144520.12]
#  [   69904.78]
#  [  551754.73]
#  [ 1034744.56]
#  [  323663.49]
#  [  102943.25]
#  [   80170.21]
#  [   49061.07]
#  [  284556.54]
#  [  149763.1 ]
#  [  231072.61]
#  [  890857.48]
#  [  540924.22]
#  [  195939.83]
#  [  970829.58]
#  [  145747.2 ]
#  [   83484.11]
#  [   45605.32]
#  [  210015.02]
#  [  328552.46]
#  [  178524.89]
#  [  868495.81]
#  [   79837.75]
#  [  142364.17]
#  [   91327.59]
#  [  441619.11]
#  [   89481.87]
#  [  239578.8 ]
#  [  306217.53]
#  [   77325.91]
#  [  150384.69]
#  [  222548.77]
# ...
