# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
Budget = pd.read_csv('actualls_all.csv')
Budget.head()
# Out:
#         State         Total     Alabama     Alaska     Arizona   Arkansas  \
# 0  state_abbr           NaN          AL         AK          AZ         AR
# 1    latitude           NaN      32.799     61.385     33.7712    34.9513
# 2   longitude           NaN    -86.8073  -152.2683   -111.3877   -92.3809
# 3        2000  3.107050e+10   557767814  177881580   667976456  328403457
# 4        2001  7.125435e+10  1205096441  227988480  1990909460  618218324
#
#    California    Colorado Connecticut   Delaware    ...     South Dakota  \
# 0          CA          CO          CT         DE    ...               SD
# 1       36.17     39.0646     41.5834    39.3498    ...          44.2853
# 2   -119.7462   -105.3272    -72.7622   -75.5148    ...         -99.4632
# 3  3792096590   370882855   288895735   85735787    ...        133366735
# 4  7895473833  1061188114   703315579  187754734    ...        296723889
#
#     Tennessee       Texas       Utah    Vermont    Virginia  Washington  \
# ...

# %%
Budget = Budget.drop(Budget.index[[[0,1,2]]])
Budget.head()
# Out:
#   State         Total     Alabama     Alaska     Arizona   Arkansas  \
# 3  2000  3.107050e+10   557767814  177881580   667976456  328403457
# 4  2001  7.125435e+10  1205096441  227988480  1990909460  618218324
# 5  2002  8.240055e+10  1387975241  260180178  2520137525  733650835
# 6  2003  9.260448e+10  1584581070  280079667  3103945066  829601733
# 7  2004  1.010000e+11  1672101861  299103691  4312713049  888970231
#
#     California    Colorado Connecticut   Delaware    ...     South Dakota  \
# 3   3792096590   370882855   288895735   85735787    ...        133366735
# 4   7895473833  1061188114   703315579  187754734    ...        296723889
# 5   9092121808  1238777106   825970250  216149404    ...        342344861
# 6   9928105199  1416997560   908683240  226632147    ...        373160375
# 7  10825485264  1665593582   965299387  286492122    ...        375611344
#
#     Tennessee       Texas       Utah    Vermont    Virginia  Washington  \
# ...

# %%
Budget = Budget.rename(index=str, columns={"State": "Year"})
Budget.head()
# Out:
#    Year         Total     Alabama     Alaska     Arizona   Arkansas  \
# 3  2000  3.107050e+10   557767814  177881580   667976456  328403457
# 4  2001  7.125435e+10  1205096441  227988480  1990909460  618218324
# 5  2002  8.240055e+10  1387975241  260180178  2520137525  733650835
# 6  2003  9.260448e+10  1584581070  280079667  3103945066  829601733
# 7  2004  1.010000e+11  1672101861  299103691  4312713049  888970231
#
#     California    Colorado Connecticut   Delaware    ...     South Dakota  \
# 3   3792096590   370882855   288895735   85735787    ...        133366735
# 4   7895473833  1061188114   703315579  187754734    ...        296723889
# 5   9092121808  1238777106   825970250  216149404    ...        342344861
# 6   9928105199  1416997560   908683240  226632147    ...        373160375
# 7  10825485264  1665593582   965299387  286492122    ...        375611344
#
#     Tennessee       Texas       Utah    Vermont    Virginia  Washington  \
# ...

# %%
budget_df = Budget.iloc[:,0:2]
budget_df.head()
# Out:
#    Year         Total
# 3  2000  3.107050e+10
# 4  2001  7.125435e+10
# 5  2002  8.240055e+10
# 6  2003  9.260448e+10
# 7  2004  1.010000e+11

# %%
budget_df.reset_index(drop=True,inplace=True)
budget_df.head()
# Out:
#    Year         Total
# 0  2000  3.107050e+10
# 1  2001  7.125435e+10
# 2  2002  8.240055e+10
# 3  2003  9.260448e+10
# 4  2004  1.010000e+11

# %%
Crime = pd.read_csv('crime_all.csv')
Crime.head()
# Out:
#    Year    Totals  ALABAMA  ALASKA  ARIZONA  ARKANSAS  CALIFORNIA  COLORADO  \
# 0  2000  11564125   202159   26641   299092    110019     1266714    171304
# 1  2001  11804921   192835   26895   322549    111296     1346557    186379
# 2  2002  11831419   200331   27745   348467    112672     1384872    195936
# 3  2003  11775044   201572   28130   342973    111141     1420637    195046
# 4  2004  11660778   201664   26331   335699    124201     1425264    197527
#
#    CONNECTICUT  DELAWARE   ...     SOUTH DAKOTA  TENNESSEE    TEXAS    UTAH  \
# 0       110091     35090   ...            17511     278218  1033311   99958
# 1       106791     32267   ...            17644     295770  1098809   96307
# 2       103719     31803   ...            17342     290961  1130292  103129
# 3       101537     33046   ...            16624     296010  1138623  105207
# 4       102078     30992   ...            16227     295147  1132256  103246
#
# ...

# %%
crime_df = Crime.iloc[:,0:2]
crime_df.head()
# Out:
#    Year    Totals
# 0  2000  11564125
# 1  2001  11804921
# 2  2002  11831419
# 3  2003  11775044
# 4  2004  11660778

# %%
crime_df = crime_df.rename(index=str, columns={"Totals": "Total_Crime"})
crime_df.head()
# Out:
#    Year  Total_Crime
# 0  2000     11564125
# 1  2001     11804921
# 2  2002     11831419
# 3  2003     11775044
# 4  2004     11660778

# %%
budget_df = budget_df.rename(index=str, columns={"Total": "Total_Budget"})
budget_df.head()
# Out:
#    Year  Total_Budget
# 0  2000  3.107050e+10
# 1  2001  7.125435e+10
# 2  2002  8.240055e+10
# 3  2003  9.260448e+10
# 4  2004  1.010000e+11

# %%
budget_df.head
# Out:
# <bound method NDFrame.head of     Year  Total_Budget
# 0   2000  3.107050e+10
# 1   2001  7.125435e+10
# 2   2002  8.240055e+10
# 3   2003  9.260448e+10
# 4   2004  1.010000e+11
# 5   2005  1.060000e+11
# 6   2006  1.070000e+11
# 7   2007  1.150000e+11
# 8   2008  1.250000e+11
# 9   2009  1.530000e+11
# 10  2010  1.860000e+11>

# %%
crime_df.head
# Out:
# <bound method NDFrame.head of     Year  Total_Crime
# 0   2000     11564125
# 1   2001     11804921
# 2   2002     11831419
# 3   2003     11775044
# 4   2004     11660778
# 5   2005     11522689
# 6   2006     11365478
# 7   2007     11214590
# 8   2008     11111207
# 9   2009     10602842
# 10  2010     10292375
# 11  2011     10229672>

# %%
crime_df = crime_df.drop(crime_df.index[[[11]]])
crime_df.head
# Out:
# <bound method NDFrame.head of     Year  Total_Crime
# 0   2000     11564125
# 1   2001     11804921
# 2   2002     11831419
# 3   2003     11775044
# 4   2004     11660778
# 5   2005     11522689
# 6   2006     11365478
# 7   2007     11214590
# 8   2008     11111207
# 9   2009     10602842
# 10  2010     10292375>

# %%
crime_df.reset_index(inplace=True)
crime_df.head()
# Out:
#   index  Year  Total_Crime
# 0     0  2000     11564125
# 1     1  2001     11804921
# 2     2  2002     11831419
# 3     3  2003     11775044
# 4     4  2004     11660778

# %%
budget_df.reset_index(inplace=True)
budget_df.head()
# Out:
#   index  Year  Total_Budget
# 0     0  2000  3.107050e+10
# 1     1  2001  7.125435e+10
# 2     2  2002  8.240055e+10
# 3     3  2003  9.260448e+10
# 4     4  2004  1.010000e+11

# %%
educrime_tot = pd.merge(budget_df, crime_df, on='index')
educrime_tot.head(15)
# Out:
#    index Year_x  Total_Budget  Year_y  Total_Crime
# 0      0   2000  3.107050e+10    2000     11564125
# 1      1   2001  7.125435e+10    2001     11804921
# 2      2   2002  8.240055e+10    2002     11831419
# 3      3   2003  9.260448e+10    2003     11775044
# 4      4   2004  1.010000e+11    2004     11660778
# 5      5   2005  1.060000e+11    2005     11522689
# 6      6   2006  1.070000e+11    2006     11365478
# 7      7   2007  1.150000e+11    2007     11214590
# 8      8   2008  1.250000e+11    2008     11111207
# 9      9   2009  1.530000e+11    2009     10602842
# 10    10   2010  1.860000e+11    2010     10292375

# %%
X = educrime_tot[['Total_Budget']]
y = educrime_tot[['Total_Crime']]
print(X.shape, y.shape)
# Out:
# (11, 1) (11, 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
model = LinearRegression()

# %%
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.9583959253737946
# Testing Score: -0.6198872327343146

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
# Out:
# Text(0.5,1,'Residual Plot')

# %%
y_train.shape
# Out:
# (8, 1)

# %%
educrime_y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
# The coefficients
print('Coefficients: \n', model.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, educrime_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, educrime_y_pred))
# Out:
# Coefficients:
#  [[ -1.44901698e-05]]
# Mean squared error: 318919879912.59
# Variance score: -0.62

# %%
print(X_test)
# Out:
#    Total_Budget
# 5  1.060000e+11
# 0  3.107050e+10
# 9  1.530000e+11

# %%
# Plot outputs
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, educrime_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
print(np.round(educrime_y_pred,2))
# Out:
# [[ 11440406.98]
#  [ 12526148.18]
#  [ 10759369.  ]]
