# %%
# Dependencies
import os
import pandas as pd
import numpy as np

# %%
# Load CSV
path = os.path.join('data', 'corrections','09_cleaned', '2000-09f.csv')
corrections_df = pd.read_csv(path)
corrections_df.head(5)
# Out:
#       State  Total (thousands of dollars)  \
# 0     Total                      58166467
# 1   Alabama                        568697
# 2    Alaska                        355032
# 3   Arizona                       1059785
# 4  Arkansas                        452316
#
#    Total justice system Direct expenditure Total  Direct current  \
# 0                                       53991300        50511278
# 1                                         537086          528819
# 2                                         341390          330932
# 3                                         949183          894196
# 4                                         439922          408189
#
#    Capital outlay  Intergovernmental expenditure    Total  \
# 0         3480022                        4175167  9787596
# 1            8267                          31611   117831
# 2           10458                          13642    63311
# 3           54987                         110602   158048
# 4           31733                          12394    73341
#
#    Police protection Direct expenditure Total  Direct current.1  \
# 0                                     8580703           7934293
# 1                                       92171             86908
# 2                                       49669             47380
# 3                                      144730            130244
# 4                                       73131             62660
#
#    Capital outlay.1    ...     Direct current.2  Capital outlay.2  \
# 0            646410    ...             12044020            326652
# 1              5263    ...               171217               793
# 2              2289    ...               112409              5688
# 3             14486    ...               138966              5264
# 4             10471    ...                97107              3287
#
#    Intergovernmental expenditure.1   Total.2  \
# 0                           878996  35129203
# 1                                0    278856
# 2                                0    173624
# 3                            37817    719690
# 4                             3423    275158
#
#    Corrections Direct expenditure Total  Direct current.3  Total.3  \
# 0                              33039925          30532965  2506960
# 1                                272905            270694     2211
# 2                                173624            171143     2481
# 3                                660223            624986    35237
# 4                                266397            248422    17975
#
#    Construction only  Intergovernmental expenditures   State.1
# 0            2014290                         2089278     Total
# 1                880                            5951   Alabama
# 2               1273                               0    Alaska
# 3              12714                           59467   Arizona
# 4              12889                            8761  Arkansas
#
# [5 rows x 23 columns]

# %%
# Select needed columns
corrections_df = corrections_df.iloc[:,[0,16]]

# %%
# Display corrections dataframe
corrections_df.head(5)
# Out:
#       State   Total.2
# 0     Total  35129203
# 1   Alabama    278856
# 2    Alaska    173624
# 3   Arizona    719690
# 4  Arkansas    275158

# %%
# Loop through directory and save Total Corrections for each year then merge dataframes
year = 2000
directory = os.path.join('data', 'corrections','09_cleaned')

for file in os.listdir(directory):
    print(file)
    file_directory = 'data\\corrections\\09_cleaned\\'
    file_path = os.path.join(file_directory, file)
    df = pd.read_csv(file_path)
    
    df = df.iloc[:,[0,16]]
    print(df.columns.values)
    df.rename(columns={list(df)[1]:year}, inplace=True)
    
    corrections_df = pd.merge(corrections_df, df, left_on='State', right_on='State')
    year += 1
    
corrections_df = corrections_df.drop(corrections_df.columns[1], axis=1)     
    
print('Number of rows: ', len(corrections_df.iloc[:,0]))
corrections_df.head()
# Out:
# 2000-09f.csv
# ['State' 'Total.2']
# 2001-09f.CSV
# ['State' 'Total.2']
# 2002-09f.csv
# ['State' 'Total.2']
# 2003-09f.csv
# ['State' 'Total.2']
# 2004-09f.csv
# ['State' 'Corrections Total']
# 2005-09f.csv
# ['State' 'Corrections Total']
# 2006-09f.csv
# ['State' 'Total.2']
# 2007-09f.csv
# ['State' 'Total.2']
# 2008-09f.csv
# ['State' 'Total.2']
# 2009-09f.csv
# ['State' 'Total.2']
# 2010-09f.csv
# ['State' 'Total.2']
# Number of rows:  51
#       State      2000      2001      2002      2003      2004      2005  \
# 0     Total  35129203  38164541  38887742  39187839  39313812  40689366
# 1   Alabama    278856    303759    331476    356928    397943    422780
# 2    Alaska    173624    172610    173844    182046    176642    196953
# 3   Arizona    719690    760323    733455    731041    790485    852183
# 4  Arkansas    275158    290520    284600    305803    351786    348766
#
#        2006      2007      2008      2009      2010
# 0  42720103  46497875  49897531  50382439  48549551
# 1    451885    514385    525281    541049    551544
# 2    210204    237144    243961    259889    270536
# 3    879959    946922   1023693   1135021   1061067
# 4    394989    331717    361537    305250    369684

# %%
# Display data types
corrections_df.dtypes
# Out:
# State    object
# 2000      int64
# 2001      int64
# 2002      int64
# 2003      int64
# 2004      int64
# 2005      int64
# 2006      int64
# 2007      int64
# 2008      int64
# 2009      int64
# 2010      int64
# dtype: object

# %%
corrections_df.to_csv('data\corrections\corrections_all.csv', sep=',', encoding='utf-8', index=False)
